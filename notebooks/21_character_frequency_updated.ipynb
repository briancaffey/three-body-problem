# %% [markdown]
# # Chinese Character Statistics
#
# This notebook will explore statistics of Chinese characters. I'll look at how the frequency of characters in the book compare to the frequency of Chinese characters in the language overall.
#
# Here are some basic things to figure out:
#
# - Get a good list of the most frequently occuring Chinese characters
#
# Here are some questions to answer:
#
# - How many characters are there in Chinese? Find an authoratative source on this.
# - How many unique characters are used in the book?
# - How many Chinese words are used in the book? Using parsed character data?
# - What is the average character lenght of a word?
# - Which characters are used in the most words?
#
# And here are some things that will be interesting to visualize:
# - What is the frequency disitribution of the characters used?
# - Histogram of paragraph lengths. How long are paragraphs in the book?

# %%
import spacy

# %%
spacy.cli.download('zh_core_web_lg')
# Out:
# Collecting zh-core-web-lg==3.6.0
#   Downloading https://github.com/explosion/spacy-models/releases/download/zh_core_web_lg-3.6.0/zh_core_web_lg-3.6.0-py3-none-any.whl (603.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 603.0/603.0 MB 5.1 MB/s eta 0:00:0000:0100:01
# Requirement already satisfied: spacy<3.7.0,>=3.6.0 in /Users/brian/git/github/three-body-problem/.venv/lib/python3.11/site-packages (from zh-core-web-lg==3.6.0) (3.6.0)
# Requirement already satisfied: spacy-pkuseg<0.1.0,>=0.0.27 in /Users/brian/git/github/three-body-problem/.venv/lib/python3.11/site-packages (from zh-core-web-lg==3.6.0) (0.0.33)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in /Users/brian/git/github/three-body-problem/.venv/lib/python3.11/site-packages (from spacy<3.7.0,>=3.6.0->zh-core-web-lg==3.6.0) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /Users/brian/git/github/three-body-problem/.venv/lib/python3.11/site-packages (from spacy<3.7.0,>=3.6.0->zh-core-web-lg==3.6.0) (1.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /Users/brian/git/github/three-body-problem/.venv/lib/python3.11/site-packages (from spacy<3.7.0,>=3.6.0->zh-core-web-lg==3.6.0) (1.0.10)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /Users/brian/git/github/three-body-problem/.venv/lib/python3.11/site-packages (from spacy<3.7.0,>=3.6.0->zh-core-web-lg==3.6.0) (2.0.8)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /Users/brian/git/github/three-body-problem/.venv/lib/python3.11/site-packages (from spacy<3.7.0,>=3.6.0->zh-core-web-lg==3.6.0) (3.0.9)
# Requirement already satisfied: thinc<8.2.0,>=8.1.8 in /Users/brian/git/github/three-body-problem/.venv/lib/python3.11/site-packages (from spacy<3.7.0,>=3.6.0->zh-core-web-lg==3.6.0) (8.1.12)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in /Users/brian/git/github/three-body-problem/.venv/lib/python3.11/site-packages (from spacy<3.7.0,>=3.6.0->zh-core-web-lg==3.6.0) (1.1.2)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in /Users/brian/git/github/three-body-problem/.venv/lib/python3.11/site-packages (from spacy<3.7.0,>=3.6.0->zh-core-web-lg==3.6.0) (2.4.8)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /Users/brian/git/github/three-body-problem/.venv/lib/python3.11/site-packages (from spacy<3.7.0,>=3.6.0->zh-core-web-lg==3.6.0) (2.0.10)
# Requirement already satisfied: typer<0.10.0,>=0.3.0 in /Users/brian/git/github/three-body-problem/.venv/lib/python3.11/site-packages (from spacy<3.7.0,>=3.6.0->zh-core-web-lg==3.6.0) (0.9.0)
# Requirement already satisfied: pathy>=0.10.0 in /Users/brian/git/github/three-body-problem/.venv/lib/python3.11/site-packages (from spacy<3.7.0,>=3.6.0->zh-core-web-lg==3.6.0) (0.10.3)
# Requirement already satisfied: smart-open<7.0.0,>=5.2.1 in /Users/brian/git/github/three-body-problem/.venv/lib/python3.11/site-packages (from spacy<3.7.0,>=3.6.0->zh-core-web-lg==3.6.0) (6.4.0)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /Users/brian/git/github/three-body-problem/.venv/lib/python3.11/site-packages (from spacy<3.7.0,>=3.6.0->zh-core-web-lg==3.6.0) (4.66.1)
# Requirement already satisfied: numpy>=1.15.0 in /Users/brian/git/github/three-body-problem/.venv/lib/python3.11/site-packages (from spacy<3.7.0,>=3.6.0->zh-core-web-lg==3.6.0) (1.26.1)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /Users/brian/git/github/three-body-problem/.venv/lib/python3.11/site-packages (from spacy<3.7.0,>=3.6.0->zh-core-web-lg==3.6.0) (2.31.0)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<1.11.0,>=1.7.4 in /Users/brian/git/github/three-body-problem/.venv/lib/python3.11/site-packages (from spacy<3.7.0,>=3.6.0->zh-core-web-lg==3.6.0) (1.10.13)
# Requirement already satisfied: jinja2 in /Users/brian/git/github/three-body-problem/.venv/lib/python3.11/site-packages (from spacy<3.7.0,>=3.6.0->zh-core-web-lg==3.6.0) (3.1.2)
# Requirement already satisfied: setuptools in /Users/brian/git/github/three-body-problem/.venv/lib/python3.11/site-packages (from spacy<3.7.0,>=3.6.0->zh-core-web-lg==3.6.0) (67.6.1)
# Requirement already satisfied: packaging>=20.0 in /Users/brian/git/github/three-body-problem/.venv/lib/python3.11/site-packages (from spacy<3.7.0,>=3.6.0->zh-core-web-lg==3.6.0) (23.2)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /Users/brian/git/github/three-body-problem/.venv/lib/python3.11/site-packages (from spacy<3.7.0,>=3.6.0->zh-core-web-lg==3.6.0) (3.3.0)
# Requirement already satisfied: typing-extensions>=4.2.0 in /Users/brian/git/github/three-body-problem/.venv/lib/python3.11/site-packages (from pydantic!=1.8,!=1.8.1,<1.11.0,>=1.7.4->spacy<3.7.0,>=3.6.0->zh-core-web-lg==3.6.0) (4.8.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/brian/git/github/three-body-problem/.venv/lib/python3.11/site-packages (from requests<3.0.0,>=2.13.0->spacy<3.7.0,>=3.6.0->zh-core-web-lg==3.6.0) (3.3.1)
# Requirement already satisfied: idna<4,>=2.5 in /Users/brian/git/github/three-body-problem/.venv/lib/python3.11/site-packages (from requests<3.0.0,>=2.13.0->spacy<3.7.0,>=3.6.0->zh-core-web-lg==3.6.0) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/brian/git/github/three-body-problem/.venv/lib/python3.11/site-packages (from requests<3.0.0,>=2.13.0->spacy<3.7.0,>=3.6.0->zh-core-web-lg==3.6.0) (1.26.18)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/brian/git/github/three-body-problem/.venv/lib/python3.11/site-packages (from requests<3.0.0,>=2.13.0->spacy<3.7.0,>=3.6.0->zh-core-web-lg==3.6.0) (2023.7.22)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in /Users/brian/git/github/three-body-problem/.venv/lib/python3.11/site-packages (from thinc<8.2.0,>=8.1.8->spacy<3.7.0,>=3.6.0->zh-core-web-lg==3.6.0) (0.7.11)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in /Users/brian/git/github/three-body-problem/.venv/lib/python3.11/site-packages (from thinc<8.2.0,>=8.1.8->spacy<3.7.0,>=3.6.0->zh-core-web-lg==3.6.0) (0.1.3)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in /Users/brian/git/github/three-body-problem/.venv/lib/python3.11/site-packages (from typer<0.10.0,>=0.3.0->spacy<3.7.0,>=3.6.0->zh-core-web-lg==3.6.0) (8.1.7)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/brian/git/github/three-body-problem/.venv/lib/python3.11/site-packages (from jinja2->spacy<3.7.0,>=3.6.0->zh-core-web-lg==3.6.0) (2.1.3)
# ✔ Download and installation successful
# You can now load the package via spacy.load('zh_core_web_lg')

# %%
zh_parser = spacy.load('zh_core_web_lg') ## disable=["parser"]

# %%
from spacy.lang.zh.examples import sentences

# %%
import json

with open("../data/books/three_body/book_data.json", "r+") as f:

    data = json.loads(f.read())

    chapters = data["chapters"][:1]

for chapter in chapters:
    chapter_text = "".join(chapter["paragraphs"])
    print(chapter_text)
    doc = zh_parser(chapter_text)
    for token in doc:
        # https://spacy.io/usage/linguistic-features#pos-tagging
        print(token.text, token.pos_, token.dep_)
# Out:
# “基石”是个平实的词，不够“炫”，却能够准确传达我们对构建中的中国科幻繁华巨厦的情感与信心，因此，我们用它来作为这套原创丛书的名字。最近十年，是科幻创作飞速发展的十年。王晋康、刘慈欣、何宏伟、韩松等一大批科幻作家发表了大量深受读者喜爱、极具开拓与探索价值的科幻佳作。科幻文学的龙头期刊更是从一本传统的《科幻世界》，发展壮大成为涵盖各个读者层的系列刊物。与此同时，科幻文学的市场环境也有了改善，省会级城市的大型书店里终于有了属于科幻的领地。仍然有人经常问及中国科幻与美国科幻的差距，但现在的答案已与十年前不同。在很多作品上（它们不再是那种毫无文学技巧与色彩、想象力拘谨的幼稚故事），这种比较已经变成了人家的牛排之于我们的土豆牛肉。差距是明显的——更准确地说，应该是“差别”——却已经无法再为它们排个名次。口味问题有了实际意义，这正是我们的科幻走向成熟的标志。与美国科幻的差距，实际上是市场化程度的差距。美国科幻从期刊到图书到影视再到游戏和玩具，已经形成了一条完整的产业链，动力十足；而我们的图书出版却仍然处于这样一种局面：读者的阅读需求不能满足的同时，出版者却感叹于科幻书那区区几千册的销量。结果，我们基本上只有为热爱而创作的科幻作家，鲜有为版税而创作的科幻作家。这不是有责任心的出版人所乐于看到的现状。科幻世界作为我国最有影响力的专业科幻出版机构，一直致力于对中国科幻的全方位推动。科幻图书出版是其中的重点之一。中国科幻需要长远眼光，需要一种务实精神，需要引入更市场化的手段，因而我们着眼于远景，而着手之处则在于一块块“基石”。需要特别说明的是，对于基石，我们并没有什么限定。因为，要建一座大厦需要各种各样的石料。对于那样一座大厦，我们满怀期待。（姚海军，《科幻世界》副总编）
# “ PUNCT punct
# 基石 NOUN nsubj
# ” PUNCT punct
# 是 VERB cop
# 个 NUM nummod
# 平实 ADJ amod
# 的 PART case
# 词 NOUN ROOT
# ， PUNCT punct
# 不够 ADV advmod
# “ PUNCT punct
# 炫 VERB conj
# ” PUNCT punct
# ， PUNCT punct
# 却 ADV advmod
# 能够 VERB aux:modal
# 准确 ADV advmod
# 传达 VERB conj
# 我们 PRON dep
# 对 ADP case
# 构建 NOUN nmod
# 中 PART case
# 的 PART case
# 中国 PROPN nmod
# 科幻 NOUN compound:nn
# 繁华 ADJ amod
# 巨厦 NOUN dep
# 的 PART case
# 情感 NOUN conj
# 与 CCONJ cc
# 信心 NOUN dobj
# ， PUNCT punct
# 因此 ADV ROOT
# ， PUNCT punct
# 我们 PRON nsubj
# 用 ADP case
# 它 PRON nmod:prep
# 来 VERB xcomp
# 作为 VERB dep
# 这 DET det
# 套 NUM mark:clf
# 原创 ADJ amod
# 丛书 NOUN nmod:assmod
# 的 PART case
# 名字 NOUN dobj
# 。 PUNCT punct
# 最近 NOUN dep
# 十 NUM dep
# 年 NUM mark:clf
# ， PUNCT punct
# 是 VERB ROOT
# 科幻 ADJ amod
# 创作 NOUN nsubj
# 飞速 ADV advmod
# 发展 VERB dep
# 的 PART mark
# 十 NUM dep
# 年 NUM mark:clf
# 。 PUNCT punct
# 王晋康 PROPN conj
# 、 PUNCT punct
# 刘慈欣 PROPN conj
# 、 PUNCT punct
# 何宏伟 PROPN conj
# 、 PUNCT punct
# 韩松 PROPN compound:nn
# 等 PART etc
# 一大 NUM nummod
# 批 NUM mark:clf
# 科幻 ADJ amod
# 作家 NOUN nsubj
# 发表 VERB ROOT
# 了 PART aux:asp
# 大量 NUM dep
# 深受 VERB dep
# 读者 NOUN dobj
# 喜爱 VERB dobj
# 、 PUNCT punct
# 极 ADV advmod
# 具 VERB conj
# 开拓 NOUN acl
# 与 CCONJ cc
# 探索 VERB conj
# 价值 NOUN dobj
# 的 PART mark
# 科幻 ADJ amod
# 佳作 NOUN dobj
# 。 PUNCT punct
# 科幻 ADJ amod
# 文学 NOUN nmod:assmod
# 的 PART case
# 龙头 NOUN compound:nn
# 期刊 NOUN nsubj
# 更 ADV advmod
# 是 VERB ROOT
# 从 ADP case
# 一 NUM nummod
# 本 NUM mark:clf
# 传统 ADJ amod
# 的 PART case
# 《 PUNCT punct
# 科幻 ADJ amod
# 世界 NOUN nmod:prep
# 》 PUNCT punct
# ， PUNCT punct
# 发展 VERB nsubj
# 壮大 VERB conj
# 成为 VERB advmod:rcomp
# 涵盖 VERB dep
# 各个 DET det
# 读者层 NOUN nmod:assmod
# 的 PART case
# 系列 NOUN compound:nn
# 刊物 NOUN dobj
# 。 PUNCT punct
# 与此同时 ADV advmod
# ， PUNCT punct
# 科幻 ADJ amod
# 文学 NOUN nmod:assmod
# 的 PART case
# 市场 NOUN compound:nn
# 环境 NOUN nsubj
# 也 ADV advmod
# 有 VERB ROOT
# 了 PART aux:asp
# 改善 NOUN dobj
# ， PUNCT punct
# 省会 NOUN compound:nn
# 级 NOUN compound:nn
# 城市 NOUN nmod:assmod
# 的 PART case
# 大型 ADJ amod
# 书店 NOUN advmod:loc
# 里 PART case
# 终于 ADV advmod
# 有 VERB conj
# 了 PART aux:asp
# 属于 VERB acl
# 科幻 NOUN dobj
# 的 PART mark
# 领地 NOUN dobj
# 。 PUNCT punct
# 仍然 ADV advmod
# 有人 VERB ROOT
# 经常 ADV advmod
# 问及 VERB ccomp
# 中国 PROPN nmod:assmod
# 科幻 NOUN conj
# 与 CCONJ cc
# 美国 PROPN nmod:assmod
# 科幻 NOUN nmod:assmod
# 的 PART case
# 差距 NOUN dobj
# ， PUNCT punct
# 但 ADV advmod
# 现在 NOUN nmod
# 的 PART case
# 答案 NOUN nsubj
# 已 ADV advmod
# 与 ADP case
# 十 NUM nmod:prep
# 年前 PART mark:clf
# 不同 VERB conj
# 。 PUNCT punct
# 在 ADP case
# 很多 NUM dep
# 作品 NOUN nmod:prep
# 上 PART case
# （ PUNCT punct
# 它们 PRON nsubj
# 不 ADV neg
# 再 ADV advmod
# 是 VERB cop
# 那种 DET det
# 毫无 VERB acl
# 文学 NOUN compound:nn
# 技巧 NOUN conj
# 与 CCONJ cc
# 色彩 NOUN conj
# 、 PUNCT punct
# 想象力 NOUN nsubj
# 拘谨 VERB amod
# 的 PART mark
# 幼稚 ADJ amod
# 故事 NOUN ROOT
# ） PUNCT punct
# ， PUNCT punct
# 这种 PRON dep
# 比较 ADV advmod
# 已经 ADV advmod
# 变成 VERB conj
# 了 PART aux:asp
# 人家 PRON nmod:assmod
# 的 PART case
# 牛排 NOUN dep
# 之 PART case
# 于 ADP dep
# 我们 PRON nmod:assmod
# 的 PART case
# 土豆 NOUN compound:nn
# 牛肉 NOUN dobj
# 。 PUNCT punct
# 差距 NOUN nsubj
# 是 VERB cop
# 明显 VERB dep
# 的 PART mark
# —— PUNCT punct
# 更 ADV advmod
# 准确 VERB advmod:dvp
# 地 PART mark
# 说 VERB ROOT
# ， PUNCT punct
# 应该 VERB aux:modal
# 是 VERB cop
# “ PUNCT punct
# 差别 NOUN ccomp
# ” PUNCT punct
# —— PUNCT punct
# 却 ADV advmod
# 已经 ADV advmod
# 无法 ADV advmod
# 再 ADV advmod
# 为 ADP case
# 它们 PRON nmod:prep
# 排 VERB conj
# 个 NUM nummod
# 名次 NOUN dobj
# 。 PUNCT punct
# 口味 NOUN compound:nn
# 问题 NOUN dep
# 有 VERB ROOT
# 了 PART aux:asp
# 实际 ADJ amod
# 意义 NOUN dobj
# ， PUNCT punct
# 这 PRON nsubj
# 正是 VERB cop
# 我们 PRON nmod:assmod
# 的 PART case
# 科幻 NOUN compound:nn
# 走向 VERB acl
# 成熟 NOUN dobj
# 的 PART case
# 标志 NOUN conj
# 。 PUNCT punct
# 与 ADP case
# 美国 PROPN nmod:assmod
# 科幻 NOUN nmod:assmod
# 的 PART case
# 差距 NOUN nmod:prep
# ， PUNCT punct
# 实际上 ADV advmod
# 是 VERB cop
# 市场化 NOUN compound:nn
# 程度 NOUN nmod:assmod
# 的 PART case
# 差距 NOUN ROOT
# 。 PUNCT punct
# 美国 PROPN nmod:assmod
# 科幻 NOUN nsubj
# 从 ADP case
# 期刊 NOUN nmod:prep
# 到 ADP case
# 图书 NOUN dep
# 到 VERB advcl:loc
# 影视 NOUN dobj
# 再 ADV advmod
# 到 VERB conj
# 游戏 NOUN conj
# 和 CCONJ cc
# 玩具 NOUN dobj
# ， PUNCT punct
# 已经 ADV advmod
# 形成 VERB conj
# 了 PART aux:asp
# 一 NUM nummod
# 条 NUM mark:clf
# 完整 ADJ amod
# 的 PART case
# 产业链 NOUN dobj
# ， PUNCT punct
# 动力 NOUN nsubj
# 十足 VERB conj
# ； PUNCT punct
# 而 ADV advmod
# 我们 PRON nmod:assmod
# 的 PART case
# 图书 NOUN compound:nn
# 出版 NOUN nsubj
# 却 ADV advmod
# 仍然 ADV advmod
# 处于 VERB conj
# 这样 ADJ amod
# 一 NUM nummod
# 种 NUM mark:clf
# 局面 NOUN dobj
# ： PUNCT punct
# 读者 NOUN nmod:assmod
# 的 PART case
# 阅读 NOUN compound:nn
# 需求 NOUN nsubj
# 不 ADV neg
# 能 VERB aux:modal
# 满足 VERB acl
# 的 PART mark
# 同时 NOUN dep
# ， PUNCT punct
# 出版者 NOUN nsubj
# 却 ADV advmod
# 感叹 VERB ROOT
# 于 ADP case
# 科幻书 PROPN nmod
# 那 PRON dep
# 区区 ADV advmod
# 几千 NUM dep
# 册 NUM mark:clf
# 的 PART case
# 销量 NOUN nmod:prep
# 。 PUNCT punct
# 结果 ADV advmod
# ， PUNCT punct
# 我们 PRON nsubj
# 基本上 ADV advmod
# 只有 ADV advmod
# 为 ADP case
# 热爱 VERB nmod:prep
# 而 CCONJ aux:prtmod
# 创作 VERB acl
# 的 PART mark
# 科幻 ADJ amod
# 作家 NOUN nsubj
# ， PUNCT punct
# 鲜有 ADV advmod
# 为 ADP case
# 版税 NOUN nmod:prep
# 而 PART aux:prtmod
# 创作 VERB acl
# 的 PART mark
# 科幻 ADJ amod
# 作家 NOUN ROOT
# 。 PUNCT punct
# 这不 ADV nsubj
# 是 VERB cop
# 有 VERB ROOT
# 责任心 NOUN nmod:assmod
# 的 PART case
# 出版人 NOUN dobj
# 所 PART aux:prtmod
# 乐于 VERB acl
# 看到 VERB ccomp
# 的 PART mark
# 现状 NOUN dobj
# 。 PUNCT punct
# 科幻 ADJ amod
# 世界 NOUN nsubj
# 作为 VERB dep
# 我国 NOUN compound:nn
# 最 ADV advmod
# 有 VERB dep
# 影响力 NOUN dobj
# 的 PART mark
# 专业 ADJ amod
# 科幻 ADJ compound:nn
# 出版 NOUN compound:nn
# 机构 NOUN dobj
# ， PUNCT punct
# 一直 ADV advmod
# 致力于 VERB ROOT
# 对 ADP case
# 中国 PROPN nmod:assmod
# 科幻 NOUN nmod
# 的 PART case
# 全方位 ADJ amod
# 推动 NOUN dobj
# 。 PUNCT punct
# 科幻 ADJ amod
# 图书 NOUN compound:nn
# 出版 NOUN nsubj
# 是 VERB cop
# 其中 NOUN nmod:assmod
# 的 PART case
# 重点 NOUN compound:nn
# 之一 NOUN ROOT
# 。 PUNCT punct
# 中国 PROPN nmod:assmod
# 科幻 NOUN nsubj
# 需要 VERB ROOT
# 长远 ADJ amod
# 眼光 NOUN dobj
# ， PUNCT punct
# 需要 VERB conj
# 一 NUM nummod
# 种 NUM mark:clf
# 务实 ADJ amod
# 精神 NOUN dobj
# ， PUNCT punct
# 需要 VERB xcomp
# 引入 VERB conj
# 更 ADV advmod
# 市场化 VERB amod
# 的 PART mark
# 手段 NOUN dobj
# ， PUNCT punct
# 因而 ADV advmod
# 我们 PRON nsubj
# 着眼 VERB conj
# 于 ADP case
# 远景 NOUN nmod:prep
# ， PUNCT punct
# 而 ADV advmod
# 着手 VERB acl
# 之 PART mark
# 处 NOUN nsubj
# 则 ADV advmod
# 在于 VERB conj
# 一块块 NUM dep
# “ PUNCT punct
# 基石 NOUN dobj
# ” PUNCT punct
# 。 PUNCT punct
# 需要 VERB xcomp
# 特别 ADV advmod
# 说明 VERB nsubj
# 的 PART mark
# 是 VERB cop
# ， PUNCT punct
# 对于 ADP case
# 基石 NOUN nmod:prep
# ， PUNCT punct
# 我们 PRON nsubj
# 并没有 ADV ROOT
# 什么 DET det
# 限定 NOUN dobj
# 。 PUNCT punct
# 因为 ADP case
# ， PUNCT ROOT
# 要 VERB xcomp
# 建 VERB dep
# 一 NUM nummod
# 座 NUM mark:clf
# 大厦 NOUN dobj
# 需要 VERB conj
# 各种各样 ADJ amod
# 的 PART mark
# 石料 NOUN dobj
# 。 PUNCT punct
# 对于 ADP case
# 那样 ADJ amod
# 一 NUM nummod
# 座 NUM mark:clf
# 大厦 NOUN nmod:prep
# ， PUNCT punct
# 我们 PRON nsubj
# 满怀 VERB ROOT
# 期待 NOUN dobj
# 。 PUNCT punct
# （ PUNCT punct
# 姚 PROPN compound:nn
# 海军 NOUN dep
# ， PUNCT punct
# 《 PUNCT punct
# 科幻 ADJ amod
# 世界 NOUN compound:nn
# 》 PUNCT punct
# 副总编 NOUN ROOT
# ） PUNCT punct

# %%
import unicodedata

def is_simplified_chinese(char):
   return 'CJK UNIFIED IDEOGRAPH' in unicodedata.name(char, '')

print(is_simplified_chinese('你')) # True
# Out:
# True

# %%
print(is_simplified_chinese('鱄')) # True
# Out:
# True

# %%
import unicodedata

def is_simplified_chinese(char):
   return 'CJK UNIFIED IDEOGRAPH' in unicodedata.name(char, '')

def count_characters(file_path):
    """
    Counts the characters in the given file.

    Args:
    file_path (str): The path to the file.

    Returns:
    dict: A dictionary with characters as keys and their counts as values.
    """
    char_count = {}

    try:
        with open(file_path, 'r', encoding='utf-8') as file:
            for line in file:
                for char in line:
                    if is_simplified_chinese(char):
                        if char in char_count:
                            char_count[char] += 1
                        else:
                            char_count[char] = 1
                    else:
                        continue
    except FileNotFoundError:
        print(f"The file at {file_path} was not found.")
        return None
    except Exception as e:
        print(f"An error occurred: {e}")
        return None

    return char_count

# %%
# Example usage
file_path = '../data/sample/file.txt'
print(count_characters(file_path))
# Out:
# {'你': 2, '好': 2, '世': 1, '界': 1}

# %%
counts = count_characters('../data/books/three_body/full_text_cn.txt')

# %%
len(counts.items())
# Out:
# 2845

# %%
counts["汪"]
# Out:
# 671

# %%
# create a dictionary of characters with frequency ranks
# https://lingua.mtsu.edu/chinese-computing/statistics/char/list.php?Which=MO


import csv

def get_frequency_dict(file_path):
    """
    This function assumes that the order of the columns is:

    order, character, frequency, percentage, pinyin, english
    """

    d = {}

    # open .tsv file
    with open(file_path) as file:

        # Passing the TSV file to
        # reader() function
        # with tab delimiter
        # This function will
        # read data from file
        tsv_file = csv.reader(file, delimiter="\t")

        # printing data line by line
        for line in tsv_file:
            print(line)
            order = line[0]
            character = line[1]
            frequency = line[2]
            percentage = line[3]
            pinyin = None
            try:
                pinyin = line[4]
            except IndexError as e:
                print("missing pinyin")
                pass

            english = None
            try:
                english = line[5]
            except IndexError as e:
                pass

            d[line[1]] = {
                'order': order,
                'character': character,
                'frequency': frequency,
                'percentage': percentage,
                'pinyin': pinyin,
                'english': english,
            }

        return d

# %%
FILE_PATH = "../data/language/frequency.tsv"
frequencies = get_frequency_dict(FILE_PATH)

# %%
# combine counts and frequencies into a single list of arrays with the following:
# [<character>, <rank>, <overall_rank>, <occurences>, <pinyin>, <english>]
# save this list of lists to a json file
# use this file for the visualization (replace old file, output.json)
import json

def build_output(counts, frequencies):
    ret = []
    for c in sorted(counts.items(), key=lambda x: x[1], reverse=True):
        print(c)
        obj = [
            c[0], # character
            c[1], # occurences
            frequencies.get(c[0], {"order": -1}).get("order"), # rank
            frequencies.get(c[0], {"english": "no translation"}).get("english"), # english
            frequencies.get(c[0], {"pinyin": "-"}).get("pinyin"), # pinyin
        ]

        ret.append(obj)

    with open("../data/language/counts.json", "w+") as f:
        json.dump(ret, f, ensure_ascii=False)

# %%
build_output(counts, frequencies)
# Out:
# ('的', 7851)
# ('一', 3208)
# ('是', 2582)
# ('了', 2528)
# ('在', 2099)
# ('这', 1938)
# ('个', 1697)
# ('不', 1639)
# ('有', 1499)
# ('我', 1312)
# ('到', 1300)
# ('人', 1279)
# ('上', 1222)
# ('他', 1218)
# ('大', 1178)
# ('地', 1106)
# ('中', 1102)
# ('那', 1099)
# ('们', 1096)
# ('文', 978)
# ('来', 961)
# ('说', 946)
# ('着', 905)
# ('时', 891)
# ('出', 857)
# ('你', 847)
# ('就', 812)
# ('看', 810)
# ('能', 749)
# ('后', 705)
# ('三', 700)
# ('下', 695)
# ('她', 679)
# ('子', 677)
# ('汪', 671)
# ('和', 630)
# ('没', 622)
# ('体', 619)
# ('都', 610)
# ('过', 602)
# ('对', 599)
# ('现', 594)
# ('淼', 592)
# ('很', 577)
# ('发', 574)
# ('炕', 3)
# ('姐', 3)
# ('偿', 3)
# ('恍', 3)
# ('洼', 3)
# ('濒', 3)
# ('齿', 3)
# ('桶', 3)
# ('萦', 2)
# ('咪', 2)
# ('拼', 2)
# ('糙', 2)
# ('镶', 2)
# ('吴', 2)
# ('慨', 2)
# ('郊', 2)
# ('鹅', 2)
# ('翩', 2)
# ('翘', 2)
# ('庸', 2)
# ('丑', 2)
# ('剖', 2)
# ('嫩', 2)
# ('俱', 2)
# ('撮', 2)
# ('喇', 2)
# ('叭', 2)
# ('炫', 2)
# ('舍', 2)
# ('伯', 2)
# ('肃', 2)
# ('竹', 2)
# ('挟', 2)
# ('颖', 2)
# ('谜', 2)
# ('嗅', 2)
# ('窃', 2)
# ('翁', 2)
# ('曹', 2)
# ('衫', 2)
# ('垮', 2)
# ('赖', 2)
# ('骚', 2)
# ('鼓', 2)
# ('勇', 2)
# ('哒', 2)
# ('朽', 2)
# ('咽', 2)
# ('舷', 2)
# ('侯', 2)
# ('挽', 2)
# ('货', 2)
# ('凿', 2)
# ('赎', 2)
# ('蜂', 2)
# ('铃', 2)
# ('瘙', 2)
# ('冗', 2)
# ('凡', 2)
# ('疏', 2)
# ('橄', 2)
# ('榄', 2)
# ('辽', 2)
# ('窝', 2)
# ('腊', 2)
# ('匠', 2)
# ('讽', 2)
# ('锈', 2)
# ('铠', 2)
# ('熔', 2)
# ('狞', 2)
# ('翅', 2)
# ('廊', 2)
# ('睽', 2)
# ('盆', 2)
# ('辰', 2)
# ('栩', 2)
# ('睑', 2)
# ('嘲', 2)
# ('褶', 2)
# ('寸', 2)
# ('牢', 2)
# ('窥', 2)
# ('谅', 2)
# ('氛', 2)
# ('堕', 2)
# ('拓', 2)
# ('佳', 2)
# ('链', 2)
# ('婉', 2)
# ('碰', 2)
# ('奈', 2)
# ('祝', 2)
# ('迄', 2)
# ('灌', 2)
# ('勾', 2)
# ('雇', 2)
# ('栏', 2)
# ('娱', 2)
# ('咝', 2)
# ('觑', 2)
# ('怡', 2)
# ('矮', 2)
# ('箭', 2)
# ('沮', 2)
# ('乒', 2)
# ('乓', 2)
# ('瞪', 2)
# ('炯', 2)
# ('卦', 2)
# ('徘', 2)
# ('徊', 2)
# ('脾', 2)
# ('宴', 2)
# ('卜', 2)
# ('呓', 2)
# ('紊', 2)
# ('吻', 2)
# ('跌', 2)
# ('腔', 2)
# ('碳', 2)
# ('叙', 2)
# ('碗', 2)
# ('棘', 2)
# ('辅', 2)
# ('佩', 2)
# ('淘', 2)
# ('褥', 2)
# ('秋', 2)
# ('铅', 2)
# ('枕', 2)
# ('闯', 2)
# ('吟', 2)
# ('歉', 2)
# ('辜', 2)
# ('斟', 2)
# ('酌', 2)
# ('踏', 2)
# ('衬', 2)
# ('啷', 2)
# ('呸', 2)
# ('萨', 2)
# ('迢', 2)
# ('川', 2)
# ('僵', 2)
# ('凯', 2)
# ('赴', 2)
# ('湍', 2)
# ('涟', 2)
# ('漪', 2)
# ('瞥', 2)
